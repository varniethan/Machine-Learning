# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 155 (delta 52), reused 123 (delta 26), pack-reused 0
# Receiving objects: 100% (155/155), 6.48 MiB | 28.71 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# # TODO -- Add residual connections to this model
# # The order of operations should similar to figure 11.5b
# # linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# # Replace this function
#   def forward(self, x):
#     h1 = self.linear1(x).relu()
#     h2 = self.linear2(h1).relu()
#     h3 = self.linear3(h2).relu()
#     return self.linear4(h3)

# BEGIN_ANSWER
  def forward(self, x):
    f = self.linear1(x)
    res1 = f+ self.linear2(f.relu())
    res2 = res1 + self.linear3(res1.relu())
    return self.linear4(res2)
# END_ANSWER

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Convert data to torch tensors.
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.622837, train error 61.33,  val loss 1.729489, percent error 67.50
# Epoch     1, train loss 1.300617, train error 48.60,  val loss 1.518693, percent error 55.50
# Epoch     2, train loss 0.997824, train error 38.38,  val loss 1.243331, percent error 48.80
# Epoch     3, train loss 0.981859, train error 37.72,  val loss 1.301184, percent error 47.20
# Epoch     4, train loss 0.792062, train error 29.95,  val loss 1.117226, percent error 41.50
# Epoch     5, train loss 0.785822, train error 29.60,  val loss 1.205244, percent error 43.50
# Epoch     6, train loss 0.725810, train error 27.75,  val loss 1.223656, percent error 43.10
# Epoch     7, train loss 0.575539, train error 21.55,  val loss 1.171421, percent error 41.50
# Epoch     8, train loss 0.543240, train error 20.62,  val loss 1.167180, percent error 38.70
# Epoch     9, train loss 0.519189, train error 19.80,  val loss 1.232607, percent error 41.30
# Epoch    10, train loss 0.415212, train error 15.30,  val loss 1.249352, percent error 38.60
# Epoch    11, train loss 0.422290, train error 16.18,  val loss 1.238353, percent error 37.60
# Epoch    12, train loss 0.436441, train error 16.10,  val loss 1.362473, percent error 38.40
# Epoch    13, train loss 0.352837, train error 13.18,  val loss 1.362671, percent error 36.40
# Epoch    14, train loss 0.408292, train error 14.75,  val loss 1.498795, percent error 39.90
# Epoch    15, train loss 0.422567, train error 15.65,  val loss 1.578773, percent error 38.80
# Epoch    16, train loss 0.347752, train error 11.93,  val loss 1.607791, percent error 40.30
# Epoch    17, train loss 0.309835, train error 11.28,  val loss 1.526318, percent error 36.70
# Epoch    18, train loss 0.267960, train error 9.97,  val loss 1.447353, percent error 35.90
# Epoch    19, train loss 0.291463, train error 10.43,  val loss 1.643427, percent error 36.90
# Epoch    20, train loss 0.109122, train error 3.47,  val loss 1.453883, percent error 33.50
# Epoch    21, train loss 0.042926, train error 0.47,  val loss 1.385088, percent error 31.50
# Epoch    22, train loss 0.023425, train error 0.10,  val loss 1.412572, percent error 30.90
# Epoch    23, train loss 0.018118, train error 0.10,  val loss 1.453035, percent error 30.70
# Epoch    24, train loss 0.013030, train error 0.00,  val loss 1.486890, percent error 30.80
# Epoch    25, train loss 0.010512, train error 0.00,  val loss 1.515293, percent error 31.40
# Epoch    26, train loss 0.009182, train error 0.00,  val loss 1.553695, percent error 31.30
# Epoch    27, train loss 0.007867, train error 0.00,  val loss 1.568572, percent error 31.50
# Epoch    28, train loss 0.007032, train error 0.00,  val loss 1.591975, percent error 31.30
# Epoch    29, train loss 0.006361, train error 0.00,  val loss 1.613331, percent error 31.60
# Epoch    30, train loss 0.005781, train error 0.00,  val loss 1.628881, percent error 31.50
# Epoch    31, train loss 0.005313, train error 0.00,  val loss 1.647922, percent error 31.70
# Epoch    32, train loss 0.004900, train error 0.00,  val loss 1.662128, percent error 31.40
# Epoch    33, train loss 0.004564, train error 0.00,  val loss 1.681027, percent error 31.40
# Epoch    34, train loss 0.004269, train error 0.00,  val loss 1.695149, percent error 31.30
# Epoch    35, train loss 0.004002, train error 0.00,  val loss 1.707293, percent error 31.40
# Epoch    36, train loss 0.003770, train error 0.00,  val loss 1.720150, percent error 31.50
# Epoch    37, train loss 0.003561, train error 0.00,  val loss 1.732275, percent error 31.40
# Epoch    38, train loss 0.003374, train error 0.00,  val loss 1.743221, percent error 31.30
# Epoch    39, train loss 0.003201, train error 0.00,  val loss 1.753650, percent error 31.30
# Epoch    40, train loss 0.003121, train error 0.00,  val loss 1.759662, percent error 31.40
# Epoch    41, train loss 0.003049, train error 0.00,  val loss 1.763975, percent error 31.30
# Epoch    42, train loss 0.002978, train error 0.00,  val loss 1.769869, percent error 31.40
# Epoch    43, train loss 0.002911, train error 0.00,  val loss 1.774617, percent error 31.40
# Epoch    44, train loss 0.002846, train error 0.00,  val loss 1.779843, percent error 31.40
# Epoch    45, train loss 0.002787, train error 0.00,  val loss 1.784068, percent error 31.30
# Epoch    46, train loss 0.002727, train error 0.00,  val loss 1.789536, percent error 31.40
# Epoch    47, train loss 0.002670, train error 0.00,  val loss 1.792805, percent error 31.40
# Epoch    48, train loss 0.002616, train error 0.00,  val loss 1.797589, percent error 31.30
# Epoch    49, train loss 0.002565, train error 0.00,  val loss 1.802384, percent error 31.50
# Epoch    50, train loss 0.002513, train error 0.00,  val loss 1.806928, percent error 31.40
# Epoch    51, train loss 0.002467, train error 0.00,  val loss 1.810623, percent error 31.40
# Epoch    52, train loss 0.002419, train error 0.00,  val loss 1.815277, percent error 31.40
# Epoch    53, train loss 0.002375, train error 0.00,  val loss 1.819605, percent error 31.20
# Epoch    54, train loss 0.002331, train error 0.00,  val loss 1.823289, percent error 31.50
# Epoch    55, train loss 0.002289, train error 0.00,  val loss 1.828169, percent error 31.40
# Epoch    56, train loss 0.002248, train error 0.00,  val loss 1.831108, percent error 31.50
# Epoch    57, train loss 0.002210, train error 0.00,  val loss 1.835885, percent error 31.40
# Epoch    58, train loss 0.002172, train error 0.00,  val loss 1.839199, percent error 31.50
# Epoch    59, train loss 0.002134, train error 0.00,  val loss 1.843114, percent error 31.50
# Epoch    60, train loss 0.002116, train error 0.00,  val loss 1.845011, percent error 31.50
# Epoch    61, train loss 0.002098, train error 0.00,  val loss 1.846736, percent error 31.50
# Epoch    62, train loss 0.002082, train error 0.00,  val loss 1.848879, percent error 31.40
# Epoch    63, train loss 0.002064, train error 0.00,  val loss 1.850480, percent error 31.50
# Epoch    64, train loss 0.002048, train error 0.00,  val loss 1.851952, percent error 31.50
# Epoch    65, train loss 0.002031, train error 0.00,  val loss 1.854010, percent error 31.70
# Epoch    66, train loss 0.002015, train error 0.00,  val loss 1.855807, percent error 31.40
# Epoch    67, train loss 0.001999, train error 0.00,  val loss 1.857505, percent error 31.60
# Epoch    68, train loss 0.001983, train error 0.00,  val loss 1.859259, percent error 31.80
# Epoch    69, train loss 0.001968, train error 0.00,  val loss 1.861110, percent error 31.70
# Epoch    70, train loss 0.001953, train error 0.00,  val loss 1.862996, percent error 31.80
# Epoch    71, train loss 0.001938, train error 0.00,  val loss 1.864308, percent error 31.80
# Epoch    72, train loss 0.001923, train error 0.00,  val loss 1.866212, percent error 31.70
# Epoch    73, train loss 0.001908, train error 0.00,  val loss 1.868223, percent error 31.80
# Epoch    74, train loss 0.001894, train error 0.00,  val loss 1.869812, percent error 31.70
# Epoch    75, train loss 0.001880, train error 0.00,  val loss 1.871461, percent error 31.60
# Epoch    76, train loss 0.001866, train error 0.00,  val loss 1.873057, percent error 31.60
# Epoch    77, train loss 0.001852, train error 0.00,  val loss 1.874894, percent error 31.70
# Epoch    78, train loss 0.001838, train error 0.00,  val loss 1.876415, percent error 31.70
# Epoch    79, train loss 0.001825, train error 0.00,  val loss 1.878024, percent error 31.60
# Epoch    80, train loss 0.001818, train error 0.00,  val loss 1.878965, percent error 31.50
# Epoch    81, train loss 0.001812, train error 0.00,  val loss 1.879509, percent error 31.50
# Epoch    82, train loss 0.001805, train error 0.00,  val loss 1.880511, percent error 31.50
# Epoch    83, train loss 0.001799, train error 0.00,  val loss 1.881300, percent error 31.50
# Epoch    84, train loss 0.001792, train error 0.00,  val loss 1.881922, percent error 31.50
# Epoch    85, train loss 0.001786, train error 0.00,  val loss 1.882945, percent error 31.50
# Epoch    86, train loss 0.001779, train error 0.00,  val loss 1.883703, percent error 31.50
# Epoch    87, train loss 0.001773, train error 0.00,  val loss 1.884400, percent error 31.50
# Epoch    88, train loss 0.001767, train error 0.00,  val loss 1.885375, percent error 31.50
# Epoch    89, train loss 0.001761, train error 0.00,  val loss 1.886089, percent error 31.40
# Epoch    90, train loss 0.001754, train error 0.00,  val loss 1.886995, percent error 31.50
# Epoch    91, train loss 0.001748, train error 0.00,  val loss 1.887740, percent error 31.40
# Epoch    92, train loss 0.001742, train error 0.00,  val loss 1.888418, percent error 31.50
# Epoch    93, train loss 0.001736, train error 0.00,  val loss 1.889079, percent error 31.50
# Epoch    94, train loss 0.001730, train error 0.00,  val loss 1.890092, percent error 31.50
# Epoch    95, train loss 0.001724, train error 0.00,  val loss 1.890924, percent error 31.40
# Epoch    96, train loss 0.001718, train error 0.00,  val loss 1.891683, percent error 31.40
# Epoch    97, train loss 0.001712, train error 0.00,  val loss 1.892415, percent error 31.40
# Epoch    98, train loss 0.001706, train error 0.00,  val loss 1.893340, percent error 31.50
# Epoch    99, train loss 0.001701, train error 0.00,  val loss 1.894101, percent error 31.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
