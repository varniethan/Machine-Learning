# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNist1D dataset as in figure 8.2a.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 155 (delta 52), reused 123 (delta 26), pack-reused 0
# Receiving objects: 100% (155/155), 6.48 MiB | 11.99 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# Try attaching to GPU
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));

# ANSWER
model = nn.Sequential(
nn.Linear(D_i, D_k),
nn.ReLU(),
nn.Linear(D_k, D_k),
nn.ReLU(),
nn.Linear(D_k, D_o))
# END_ANSWER

def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  # ANSWER
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
  # END_ANSWER

# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    print(pred.shape)
    print(y_batch.shape)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     0, train loss 1.588524, train error 63.45,  test loss 1.658574, test error 67.80
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     1, train loss 1.331115, train error 50.22,  test loss 1.485303, test error 59.30
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     2, train loss 1.149723, train error 41.72,  test loss 1.318194, test error 52.00
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     3, train loss 0.980876, train error 35.25,  test loss 1.221345, test error 46.60
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     4, train loss 0.932885, train error 33.82,  test loss 1.239760, test error 47.00
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     5, train loss 0.809684, train error 28.78,  test loss 1.168096, test error 45.40
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     6, train loss 0.746943, train error 26.95,  test loss 1.171751, test error 43.00
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     7, train loss 0.616817, train error 20.38,  test loss 1.120205, test error 42.10
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     8, train loss 0.555462, train error 18.03,  test loss 1.088892, test error 40.40
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch     9, train loss 0.504501, train error 16.95,  test loss 1.104521, test error 40.40
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    10, train loss 0.402283, train error 11.28,  test loss 1.037336, test error 39.20
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    11, train loss 0.365937, train error 9.93,  test loss 1.054049, test error 38.10
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    12, train loss 0.347103, train error 9.12,  test loss 1.065000, test error 38.60
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    13, train loss 0.314447, train error 8.47,  test loss 1.069756, test error 37.40
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    14, train loss 0.291072, train error 7.78,  test loss 1.109576, test error 39.60
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    15, train loss 0.262739, train error 6.40,  test loss 1.086561, test error 37.00
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    16, train loss 0.236247, train error 4.78,  test loss 1.122779, test error 37.40
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    17, train loss 0.215720, train error 4.65,  test loss 1.123057, test error 38.90
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    18, train loss 0.196385, train error 3.85,  test loss 1.165327, test error 37.70
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    19, train loss 0.170356, train error 2.32,  test loss 1.165295, test error 37.00
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    20, train loss 0.154606, train error 1.62,  test loss 1.164893, test error 38.20
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    21, train loss 0.146116, train error 1.43,  test loss 1.162245, test error 38.00
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    22, train loss 0.134795, train error 1.32,  test loss 1.181195, test error 37.90
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    23, train loss 0.127357, train error 0.85,  test loss 1.199850, test error 38.00
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    24, train loss 0.121080, train error 0.75,  test loss 1.191757, test error 37.80
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    25, train loss 0.117074, train error 0.70,  test loss 1.214158, test error 38.60
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    26, train loss 0.110060, train error 0.57,  test loss 1.221732, test error 38.80
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    27, train loss 0.103553, train error 0.55,  test loss 1.225411, test error 38.10
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# ...
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    34, train loss 0.082172, train error 0.28,  test loss 1.277457, test error 37.50
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    35, train loss 0.080794, train error 0.30,  test loss 1.283320, test error 37.70
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    36, train loss 0.078487, train error 0.25,  test loss 1.287580, test error 37.90
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    37, train loss 0.076521, train error 0.20,  test loss 1.286827, test error 38.10
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    38, train loss 0.074476, train error 0.18,  test loss 1.293441, test error 37.50
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    39, train loss 0.073841, train error 0.22,  test loss 1.296401, test error 37.90
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    40, train loss 0.072025, train error 0.12,  test loss 1.304202, test error 38.10
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# Epoch    41, train loss 0.071080, train error 0.18,  test loss 1.303158, test error 37.60
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# torch.Size([100, 10])
# torch.Size([100])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ba09d476082c> in <cell line: 27>()
#      27 for epoch in range(n_epoch):
#      28   # loop over batches
# ---> 29   for i, batch in enumerate(data_loader):
#      30     # retrieve inputs and labels for this batch
#      31     x_batch, y_batch = batch
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     631                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632                 self._reset()  # type: ignore[call-arg]
# --> 633             data = self._next_data()
#     634             self._num_yielded += 1
#     635             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     675     def _next_data(self):
#     676         index = self._next_index()  # may raise StopIteration
# --> 677         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678         if self._pin_memory:
#     679             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
# ---> 54         return self.collate_fn(data)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#     263             >>> default_collate(batch)  # Handle `CustomType` automatically
#     264     """
# --> 265     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/collate.py in collate(batch, collate_fn_map)
#     140
#     141         if isinstance(elem, tuple):
# --> 142             return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143         else:
#     144             try:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/collate.py in <listcomp>(.0)
#     140
#     141         if isinstance(elem, tuple):
# --> 142             return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143         else:
#     144             try:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/collate.py in collate(batch, collate_fn_map)
#     117     if collate_fn_map is not None:
#     118         if elem_type in collate_fn_map:
# --> 119             return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     120
#     121         for collate_type in collate_fn_map:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/collate.py in collate_tensor_fn(batch, collate_fn_map)
#     160         storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     161         out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 162     return torch.stack(batch, 0, out=out)
#     163
#     164
#
# KeyboardInterrupt:

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the results.
