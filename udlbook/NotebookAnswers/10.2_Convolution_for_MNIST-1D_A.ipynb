# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 155 (delta 52), reused 123 (delta 26), pack-reused 0
# Receiving objects: 100% (155/155), 6.48 MiB | 21.96 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the folowing layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3x3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3x3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3x3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# Replace the following function:
model = nn.Sequential(
nn.Flatten(),
nn.Linear(40, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# BEGIN_SOLUTION
model = nn.Sequential(
nn.Conv1d(1,15,3,stride=2,padding='valid'),
nn.ReLU(),
nn.Conv1d(15,15,3,stride=2,padding='valid'),
nn.ReLU(),
nn.Conv1d(15,15,3,stride=2,padding='valid'),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60,10))
#END_SOLUTION

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.103681, train error 39.62,  val loss 1.099428, percent error 39.90
# Epoch     1, train loss 0.625352, train error 23.10,  val loss 0.675219, percent error 24.30
# Epoch     2, train loss 0.505931, train error 17.97,  val loss 0.568561, percent error 20.70
# Epoch     3, train loss 0.441261, train error 15.95,  val loss 0.521625, percent error 19.90
# Epoch     4, train loss 0.345468, train error 11.60,  val loss 0.447720, percent error 15.30
# Epoch     5, train loss 0.319872, train error 10.50,  val loss 0.428427, percent error 14.90
# Epoch     6, train loss 0.348570, train error 11.82,  val loss 0.490729, percent error 17.40
# Epoch     7, train loss 0.311460, train error 10.90,  val loss 0.404245, percent error 14.10
# Epoch     8, train loss 0.305066, train error 10.38,  val loss 0.430860, percent error 13.50
# Epoch     9, train loss 0.261683, train error 9.50,  val loss 0.392387, percent error 13.50
# Epoch    10, train loss 0.241592, train error 8.65,  val loss 0.390170, percent error 14.10
# Epoch    11, train loss 0.235751, train error 8.10,  val loss 0.333996, percent error 11.00
# Epoch    12, train loss 0.179910, train error 6.25,  val loss 0.319994, percent error 12.30
# Epoch    13, train loss 0.213753, train error 7.75,  val loss 0.390645, percent error 12.90
# Epoch    14, train loss 0.231829, train error 7.97,  val loss 0.378669, percent error 11.80
# Epoch    15, train loss 0.147877, train error 5.35,  val loss 0.296568, percent error 8.40
# Epoch    16, train loss 0.130396, train error 4.40,  val loss 0.296530, percent error 9.80
# Epoch    17, train loss 0.153116, train error 5.60,  val loss 0.340710, percent error 11.10
# Epoch    18, train loss 0.146756, train error 5.40,  val loss 0.362003, percent error 10.60
# Epoch    19, train loss 0.147460, train error 5.05,  val loss 0.325367, percent error 9.70
# Epoch    20, train loss 0.106924, train error 3.70,  val loss 0.314199, percent error 9.30
# Epoch    21, train loss 0.077186, train error 2.28,  val loss 0.279143, percent error 9.60
# Epoch    22, train loss 0.078035, train error 2.47,  val loss 0.290628, percent error 8.80
# Epoch    23, train loss 0.071078, train error 2.15,  val loss 0.284957, percent error 8.10
# Epoch    24, train loss 0.072490, train error 2.12,  val loss 0.292281, percent error 8.70
# Epoch    25, train loss 0.066231, train error 2.00,  val loss 0.299627, percent error 8.20
# Epoch    26, train loss 0.057714, train error 1.55,  val loss 0.286694, percent error 8.60
# Epoch    27, train loss 0.051280, train error 1.10,  val loss 0.292892, percent error 8.60
# Epoch    28, train loss 0.068677, train error 2.22,  val loss 0.320227, percent error 8.90
# Epoch    29, train loss 0.051077, train error 1.53,  val loss 0.296737, percent error 8.80
# Epoch    30, train loss 0.053951, train error 1.50,  val loss 0.294846, percent error 8.90
# Epoch    31, train loss 0.044356, train error 0.95,  val loss 0.288351, percent error 8.40
# Epoch    32, train loss 0.045197, train error 1.30,  val loss 0.305689, percent error 8.20
# Epoch    33, train loss 0.052407, train error 1.50,  val loss 0.324376, percent error 8.90
# Epoch    34, train loss 0.041951, train error 1.12,  val loss 0.315508, percent error 8.20
# Epoch    35, train loss 0.050021, train error 1.57,  val loss 0.333962, percent error 8.70
# Epoch    36, train loss 0.040434, train error 1.05,  val loss 0.307835, percent error 8.30
# Epoch    37, train loss 0.032877, train error 0.68,  val loss 0.307033, percent error 8.40
# Epoch    38, train loss 0.034896, train error 0.75,  val loss 0.312308, percent error 8.00
# Epoch    39, train loss 0.033027, train error 0.78,  val loss 0.331843, percent error 8.20
# Epoch    40, train loss 0.025198, train error 0.38,  val loss 0.318706, percent error 8.10
# Epoch    41, train loss 0.025572, train error 0.35,  val loss 0.332624, percent error 8.50
# Epoch    42, train loss 0.024621, train error 0.32,  val loss 0.335297, percent error 8.30
# Epoch    43, train loss 0.023364, train error 0.28,  val loss 0.330676, percent error 8.90
# Epoch    44, train loss 0.023723, train error 0.30,  val loss 0.336839, percent error 8.60
# Epoch    45, train loss 0.023354, train error 0.38,  val loss 0.331739, percent error 8.60
# Epoch    46, train loss 0.021604, train error 0.28,  val loss 0.335951, percent error 8.50
# Epoch    47, train loss 0.023163, train error 0.35,  val loss 0.347325, percent error 8.10
# Epoch    48, train loss 0.020495, train error 0.18,  val loss 0.343549, percent error 8.60
# Epoch    49, train loss 0.020283, train error 0.25,  val loss 0.345547, percent error 8.30
# Epoch    50, train loss 0.019372, train error 0.20,  val loss 0.348861, percent error 8.60
# Epoch    51, train loss 0.019413, train error 0.30,  val loss 0.347750, percent error 8.50
# Epoch    52, train loss 0.019206, train error 0.30,  val loss 0.355763, percent error 8.80
# Epoch    53, train loss 0.018549, train error 0.20,  val loss 0.354983, percent error 8.90
# Epoch    54, train loss 0.018383, train error 0.22,  val loss 0.357811, percent error 8.50
# Epoch    55, train loss 0.018076, train error 0.20,  val loss 0.363704, percent error 8.80
# Epoch    56, train loss 0.017332, train error 0.15,  val loss 0.365952, percent error 8.40
# Epoch    57, train loss 0.017400, train error 0.12,  val loss 0.363395, percent error 8.70
# Epoch    58, train loss 0.016907, train error 0.18,  val loss 0.369383, percent error 8.60
# Epoch    59, train loss 0.016056, train error 0.10,  val loss 0.368240, percent error 8.70
# Epoch    60, train loss 0.015609, train error 0.15,  val loss 0.372096, percent error 8.60
# Epoch    61, train loss 0.015297, train error 0.12,  val loss 0.371837, percent error 8.60
# Epoch    62, train loss 0.015235, train error 0.18,  val loss 0.370750, percent error 8.80
# Epoch    63, train loss 0.014847, train error 0.15,  val loss 0.372510, percent error 8.80
# Epoch    64, train loss 0.014668, train error 0.12,  val loss 0.374796, percent error 8.80
# Epoch    65, train loss 0.015134, train error 0.15,  val loss 0.377881, percent error 8.60
# Epoch    66, train loss 0.014518, train error 0.10,  val loss 0.377798, percent error 8.70
# Epoch    67, train loss 0.014742, train error 0.07,  val loss 0.382004, percent error 8.80
# Epoch    68, train loss 0.014334, train error 0.12,  val loss 0.380100, percent error 8.70
# Epoch    69, train loss 0.014628, train error 0.10,  val loss 0.380833, percent error 8.90
# Epoch    70, train loss 0.013972, train error 0.10,  val loss 0.382144, percent error 8.90
# Epoch    71, train loss 0.013806, train error 0.07,  val loss 0.383866, percent error 8.90
# Epoch    72, train loss 0.013869, train error 0.12,  val loss 0.383587, percent error 8.70
# Epoch    73, train loss 0.013482, train error 0.07,  val loss 0.386877, percent error 9.00
# Epoch    74, train loss 0.013304, train error 0.10,  val loss 0.385508, percent error 8.90
# Epoch    75, train loss 0.013213, train error 0.07,  val loss 0.387595, percent error 8.90
# Epoch    76, train loss 0.013119, train error 0.05,  val loss 0.388688, percent error 8.80
# Epoch    77, train loss 0.012995, train error 0.10,  val loss 0.390481, percent error 8.90
# Epoch    78, train loss 0.012884, train error 0.07,  val loss 0.391702, percent error 9.00
# Epoch    79, train loss 0.012783, train error 0.07,  val loss 0.392963, percent error 9.00
# Epoch    80, train loss 0.012597, train error 0.05,  val loss 0.394413, percent error 9.00
# Epoch    81, train loss 0.012542, train error 0.05,  val loss 0.393074, percent error 8.90
# Epoch    82, train loss 0.012482, train error 0.05,  val loss 0.394120, percent error 9.00
# Epoch    83, train loss 0.012485, train error 0.05,  val loss 0.394460, percent error 8.90
# Epoch    84, train loss 0.012400, train error 0.05,  val loss 0.395964, percent error 8.80
# Epoch    85, train loss 0.012376, train error 0.03,  val loss 0.397212, percent error 8.90
# Epoch    86, train loss 0.012285, train error 0.05,  val loss 0.397557, percent error 9.10
# Epoch    87, train loss 0.012310, train error 0.05,  val loss 0.397364, percent error 9.00
# Epoch    88, train loss 0.012166, train error 0.03,  val loss 0.397470, percent error 9.10
# Epoch    89, train loss 0.012134, train error 0.05,  val loss 0.397324, percent error 8.90
# Epoch    90, train loss 0.012047, train error 0.05,  val loss 0.399083, percent error 9.00
# Epoch    91, train loss 0.012014, train error 0.03,  val loss 0.401159, percent error 9.00
# Epoch    92, train loss 0.011934, train error 0.03,  val loss 0.399874, percent error 9.00
# Epoch    93, train loss 0.011871, train error 0.03,  val loss 0.401518, percent error 9.00
# Epoch    94, train loss 0.011953, train error 0.03,  val loss 0.401193, percent error 9.00
# Epoch    95, train loss 0.011775, train error 0.03,  val loss 0.401480, percent error 9.00
# Epoch    96, train loss 0.011912, train error 0.03,  val loss 0.401796, percent error 9.00
# Epoch    97, train loss 0.011673, train error 0.03,  val loss 0.402450, percent error 8.90
# Epoch    98, train loss 0.011608, train error 0.03,  val loss 0.402450, percent error 9.20
# Epoch    99, train loss 0.011585, train error 0.03,  val loss 0.402663, percent error 9.00
