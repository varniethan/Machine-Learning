# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 155 (delta 52), reused 123 (delta 26), pack-reused 0
# Receiving objects: 100% (155/155), 6.48 MiB | 4.16 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# ANSWER:
#
# 1.  It should reach zero when the number of parameters is the greater than the amount of data.  This first happens at a hidden dimension of 45.
# 2. The minima will be about a third of the way to this point.  This would be a hidden dimension of 15.
# 3.  The maximum will occur when the number of parameters is about the same as the amount of data.  This will be between 40 and 45 hidden units per layer.
#
# END_ANSWER

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.292846, train error 89.12,  test loss 2.287628, test error 89.82
# Epoch   100, train loss 1.874792, train error 70.70,  test loss 1.712218, test error 68.68
# Epoch   200, train loss 1.868257, train error 70.18,  test loss 1.713933, test error 68.72
# Epoch   300, train loss 1.862050, train error 70.45,  test loss 1.699812, test error 68.50
# Epoch   400, train loss 1.859961, train error 70.12,  test loss 1.702051, test error 68.10
# Epoch   500, train loss 1.868932, train error 70.15,  test loss 1.709958, test error 69.28
# Epoch   600, train loss 1.858654, train error 70.60,  test loss 1.700348, test error 67.95
# Epoch   700, train loss 1.860086, train error 70.00,  test loss 1.698710, test error 67.88
# Epoch   800, train loss 1.856744, train error 70.12,  test loss 1.697974, test error 67.72
# Epoch   900, train loss 1.860684, train error 70.03,  test loss 1.701418, test error 68.70
# Training model with   4 hidden variables
# Epoch     0, train loss 2.278959, train error 85.97,  test loss 2.272382, test error 85.05
# Epoch   100, train loss 1.898806, train error 69.68,  test loss 1.762501, test error 68.97
# Epoch   200, train loss 1.873915, train error 68.65,  test loss 1.730642, test error 67.80
# Epoch   300, train loss 1.856273, train error 68.45,  test loss 1.697899, test error 66.55
# Epoch   400, train loss 1.840900, train error 68.35,  test loss 1.673540, test error 66.97
# Epoch   500, train loss 1.769333, train error 63.40,  test loss 1.554892, test error 61.15
# Epoch   600, train loss 1.752763, train error 63.78,  test loss 1.551447, test error 60.25
# Epoch   700, train loss 1.737331, train error 62.58,  test loss 1.540304, test error 59.85
# Epoch   800, train loss 1.736959, train error 63.12,  test loss 1.532942, test error 60.65
# Epoch   900, train loss 1.733165, train error 62.90,  test loss 1.545744, test error 61.08
# Training model with   6 hidden variables
# Epoch     0, train loss 2.187145, train error 81.40,  test loss 2.151538, test error 79.35
# Epoch   100, train loss 1.690490, train error 59.95,  test loss 1.513821, test error 58.45
# Epoch   200, train loss 1.660412, train error 59.05,  test loss 1.500335, test error 57.90
# Epoch   300, train loss 1.641413, train error 58.22,  test loss 1.496575, test error 57.92
# Epoch   400, train loss 1.642781, train error 59.08,  test loss 1.509373, test error 57.50
# Epoch   500, train loss 1.629690, train error 58.12,  test loss 1.501829, test error 57.80
# Epoch   600, train loss 1.625235, train error 58.75,  test loss 1.503468, test error 57.85
# Epoch   700, train loss 1.624305, train error 57.97,  test loss 1.502407, test error 57.05
# Epoch   800, train loss 1.622298, train error 57.58,  test loss 1.507886, test error 57.38
# Epoch   900, train loss 1.615974, train error 58.12,  test loss 1.498262, test error 57.28
# Training model with   8 hidden variables
# Epoch     0, train loss 2.231853, train error 85.38,  test loss 2.217099, test error 85.18
# Epoch   100, train loss 1.527138, train error 52.03,  test loss 1.357167, test error 50.55
# Epoch   200, train loss 1.507941, train error 51.20,  test loss 1.363955, test error 50.70
# Epoch   300, train loss 1.494408, train error 51.58,  test loss 1.359872, test error 50.65
# Epoch   400, train loss 1.486683, train error 50.67,  test loss 1.374442, test error 50.90
# Epoch   500, train loss 1.480190, train error 50.62,  test loss 1.365214, test error 50.17
# Epoch   600, train loss 1.480207, train error 50.12,  test loss 1.377432, test error 50.33
# Epoch   700, train loss 1.474863, train error 50.25,  test loss 1.369547, test error 50.28
# Epoch   800, train loss 1.471790, train error 50.17,  test loss 1.380988, test error 50.38
# Epoch   900, train loss 1.470986, train error 50.28,  test loss 1.379629, test error 50.25
# Training model with  10 hidden variables
# Epoch     0, train loss 2.175607, train error 80.93,  test loss 2.147688, test error 80.55
# Epoch   100, train loss 1.489076, train error 48.97,  test loss 1.322629, test error 49.33
# Epoch   200, train loss 1.448690, train error 47.80,  test loss 1.315120, test error 48.08
# Epoch   300, train loss 1.436170, train error 47.25,  test loss 1.319175, test error 48.42
# Epoch   400, train loss 1.431954, train error 47.30,  test loss 1.336936, test error 49.28
# Epoch   500, train loss 1.424455, train error 47.42,  test loss 1.341379, test error 49.10
# Epoch   600, train loss 1.418242, train error 47.00,  test loss 1.352541, test error 50.05
# Epoch   700, train loss 1.407439, train error 46.88,  test loss 1.344164, test error 48.95
# Epoch   800, train loss 1.403193, train error 46.62,  test loss 1.350002, test error 48.70
# Epoch   900, train loss 1.398095, train error 46.53,  test loss 1.356017, test error 48.80
# Training model with  14 hidden variables
# Epoch     0, train loss 2.121029, train error 79.90,  test loss 2.081732, test error 78.45
# Epoch   100, train loss 1.399664, train error 46.28,  test loss 1.262503, test error 47.35
# Epoch   200, train loss 1.324126, train error 44.53,  test loss 1.271354, test error 46.55
# Epoch   300, train loss 1.300228, train error 43.92,  test loss 1.317359, test error 47.15
# Epoch   400, train loss 1.294105, train error 43.25,  test loss 1.349655, test error 48.50
# Epoch   500, train loss 1.277299, train error 41.88,  test loss 1.356879, test error 47.83
# Epoch   600, train loss 1.261740, train error 41.45,  test loss 1.368915, test error 47.83
# Epoch   700, train loss 1.254699, train error 41.50,  test loss 1.394324, test error 47.88
# Epoch   800, train loss 1.247321, train error 41.53,  test loss 1.389698, test error 47.80
# Epoch   900, train loss 1.247313, train error 41.72,  test loss 1.406001, test error 48.17
# Training model with  18 hidden variables
# Epoch     0, train loss 2.250850, train error 83.95,  test loss 2.242889, test error 83.05
# Epoch   100, train loss 1.397935, train error 47.12,  test loss 1.385716, test error 51.92
# Epoch   200, train loss 1.288704, train error 42.92,  test loss 1.391500, test error 50.60
# Epoch   300, train loss 1.246441, train error 41.95,  test loss 1.435711, test error 51.03
# Epoch   400, train loss 1.217544, train error 40.65,  test loss 1.455634, test error 51.10
# Epoch   500, train loss 1.200797, train error 40.42,  test loss 1.479768, test error 50.90
# Epoch   600, train loss 1.196486, train error 40.60,  test loss 1.503337, test error 51.25
# Epoch   700, train loss 1.193466, train error 41.38,  test loss 1.528007, test error 51.60
# Epoch   800, train loss 1.186485, train error 41.58,  test loss 1.538626, test error 51.92
# Epoch   900, train loss 1.170519, train error 40.28,  test loss 1.542129, test error 52.08
# Training model with  22 hidden variables
# Epoch     0, train loss 2.123924, train error 79.38,  test loss 2.053404, test error 77.95
# Epoch   100, train loss 1.338201, train error 45.17,  test loss 1.384446, test error 52.78
# Epoch   200, train loss 1.217058, train error 40.75,  test loss 1.431863, test error 51.28
# Epoch   300, train loss 1.167228, train error 39.50,  test loss 1.493376, test error 51.38
# Epoch   400, train loss 1.123466, train error 38.15,  test loss 1.570159, test error 52.95
# Epoch   500, train loss 1.104990, train error 38.05,  test loss 1.629834, test error 53.33
# Epoch   600, train loss 1.086702, train error 37.30,  test loss 1.656846, test error 53.10
# Epoch   700, train loss 1.072254, train error 37.50,  test loss 1.701967, test error 53.78
# Epoch   800, train loss 1.088068, train error 37.90,  test loss 1.747816, test error 53.17
# Epoch   900, train loss 1.054713, train error 36.47,  test loss 1.755690, test error 53.42
# Training model with  26 hidden variables
# Epoch     0, train loss 2.236570, train error 83.22,  test loss 2.226274, test error 82.88
# Epoch   100, train loss 1.269966, train error 42.50,  test loss 1.349774, test error 50.83
# Epoch   200, train loss 1.082560, train error 36.80,  test loss 1.474425, test error 51.53
# Epoch   300, train loss 1.000743, train error 34.38,  test loss 1.658340, test error 52.75
# Epoch   400, train loss 0.943233, train error 32.28,  test loss 1.805595, test error 54.50
# Epoch   500, train loss 0.919178, train error 31.80,  test loss 1.879787, test error 53.40
# Epoch   600, train loss 0.897513, train error 31.05,  test loss 2.005246, test error 55.10
# Epoch   700, train loss 0.881168, train error 30.45,  test loss 2.033148, test error 54.75
# Epoch   800, train loss 0.875220, train error 30.68,  test loss 2.126872, test error 56.45
# Epoch   900, train loss 0.858895, train error 29.45,  test loss 2.228789, test error 56.22
# Training model with  30 hidden variables
# Epoch     0, train loss 2.167749, train error 79.50,  test loss 2.132622, test error 78.30
# Epoch   100, train loss 1.145779, train error 38.47,  test loss 1.367856, test error 49.75
# Epoch   200, train loss 0.992438, train error 34.43,  test loss 1.575791, test error 51.90
# Epoch   300, train loss 0.894085, train error 30.53,  test loss 1.773101, test error 54.12
# Epoch   400, train loss 0.832148, train error 28.80,  test loss 1.980649, test error 54.80
# Epoch   500, train loss 0.809747, train error 28.65,  test loss 2.184755, test error 55.38
# Epoch   600, train loss 0.746588, train error 26.12,  test loss 2.352102, test error 56.05
# Epoch   700, train loss 0.727694, train error 26.05,  test loss 2.551471, test error 56.62
# Epoch   800, train loss 0.716213, train error 25.40,  test loss 2.768272, test error 57.62
# Epoch   900, train loss 0.711551, train error 25.78,  test loss 2.964720, test error 57.65
# Training model with  35 hidden variables
# Epoch     0, train loss 2.125949, train error 79.85,  test loss 2.070020, test error 78.50
# Epoch   100, train loss 1.039785, train error 34.18,  test loss 1.366341, test error 48.22
# Epoch   200, train loss 0.803200, train error 25.80,  test loss 1.635013, test error 50.22
# Epoch   300, train loss 0.695704, train error 22.82,  test loss 1.958130, test error 52.05
# Epoch   400, train loss 0.656821, train error 22.45,  test loss 2.249473, test error 53.58
# Epoch   500, train loss 0.595486, train error 20.00,  test loss 2.529953, test error 54.58
# Epoch   600, train loss 0.553897, train error 18.53,  test loss 2.824604, test error 55.53
# Epoch   700, train loss 0.520080, train error 18.03,  test loss 3.114512, test error 55.35
# Epoch   800, train loss 0.495743, train error 17.00,  test loss 3.359035, test error 55.28
# Epoch   900, train loss 0.480221, train error 16.88,  test loss 3.582811, test error 56.30
# Training model with  40 hidden variables
# Epoch     0, train loss 2.136808, train error 78.28,  test loss 2.104288, test error 77.40
# Epoch   100, train loss 0.930542, train error 29.57,  test loss 1.414197, test error 50.00
# Epoch   200, train loss 0.672974, train error 21.78,  test loss 1.939724, test error 54.08
# Epoch   300, train loss 0.521560, train error 17.47,  test loss 2.546641, test error 54.42
# Epoch   400, train loss 0.440241, train error 14.97,  test loss 3.241823, test error 56.88
# Epoch   500, train loss 0.410305, train error 14.80,  test loss 3.799364, test error 56.80
# Epoch   600, train loss 0.362095, train error 12.78,  test loss 4.413571, test error 57.53
# Epoch   700, train loss 0.289668, train error 10.20,  test loss 4.968240, test error 56.85
# Epoch   800, train loss 0.331819, train error 12.20,  test loss 5.634854, test error 57.12
# Epoch   900, train loss 0.418993, train error 14.43,  test loss 6.315033, test error 57.78
# Training model with  45 hidden variables
# Epoch     0, train loss 2.092001, train error 78.25,  test loss 2.061504, test error 78.20
# Epoch   100, train loss 0.854086, train error 27.80,  test loss 1.485020, test error 51.03
# Epoch   200, train loss 0.568176, train error 19.10,  test loss 2.165454, test error 53.17
# Epoch   300, train loss 0.368250, train error 12.28,  test loss 3.039274, test error 53.90
# Epoch   400, train loss 0.266767, train error 9.22,  test loss 4.112852, test error 54.83
# Epoch   500, train loss 0.198898, train error 6.78,  test loss 5.234497, test error 56.88
# Epoch   600, train loss 0.204695, train error 7.68,  test loss 6.371302, test error 57.15
# Epoch   700, train loss 0.228110, train error 8.32,  test loss 7.638922, test error 57.35
# Epoch   800, train loss 0.101381, train error 3.62,  test loss 8.461665, test error 57.35
# Epoch   900, train loss 0.007022, train error 0.00,  test loss 9.124009, test error 56.55
# Training model with  50 hidden variables
# Epoch     0, train loss 2.069549, train error 78.57,  test loss 1.999932, test error 77.55
# Epoch   100, train loss 0.769317, train error 24.38,  test loss 1.611061, test error 51.92
# Epoch   200, train loss 0.365963, train error 10.25,  test loss 2.735859, test error 55.55
# Epoch   300, train loss 0.200052, train error 6.47,  test loss 4.383930, test error 57.60
# Epoch   400, train loss 0.035882, train error 0.03,  test loss 6.142272, test error 57.90
# Epoch   500, train loss 0.015169, train error 0.00,  test loss 7.287847, test error 57.85
# Epoch   600, train loss 0.009250, train error 0.00,  test loss 8.029991, test error 58.20
# Epoch   700, train loss 0.006582, train error 0.00,  test loss 8.575436, test error 58.20
# Epoch   800, train loss 0.005007, train error 0.00,  test loss 9.005853, test error 58.25
# Epoch   900, train loss 0.004030, train error 0.00,  test loss 9.359116, test error 58.33
# Training model with  55 hidden variables
# Epoch     0, train loss 2.100638, train error 77.00,  test loss 2.051456, test error 76.72
# Epoch   100, train loss 0.621555, train error 19.03,  test loss 1.724032, test error 52.20
# Epoch   200, train loss 0.220660, train error 5.55,  test loss 3.168025, test error 55.42
# Epoch   300, train loss 0.051773, train error 0.35,  test loss 5.036780, test error 57.28
# Epoch   400, train loss 0.014225, train error 0.00,  test loss 6.013278, test error 56.72
# Epoch   500, train loss 0.008322, train error 0.00,  test loss 6.662264, test error 56.90
# Epoch   600, train loss 0.005739, train error 0.00,  test loss 7.129181, test error 57.22
# Epoch   700, train loss 0.004317, train error 0.00,  test loss 7.483984, test error 57.22
# Epoch   800, train loss 0.003399, train error 0.00,  test loss 7.780785, test error 57.12
# Epoch   900, train loss 0.002785, train error 0.00,  test loss 8.022041, test error 57.28
# Training model with  60 hidden variables
# Epoch     0, train loss 2.088760, train error 78.53,  test loss 2.036757, test error 78.95
# Epoch   100, train loss 0.552993, train error 16.45,  test loss 1.732390, test error 52.22
# Epoch   200, train loss 0.127706, train error 1.90,  test loss 3.449687, test error 54.45
# Epoch   300, train loss 0.020873, train error 0.00,  test loss 4.959687, test error 54.38
# Epoch   400, train loss 0.009963, train error 0.00,  test loss 5.718092, test error 54.40
# Epoch   500, train loss 0.006290, train error 0.00,  test loss 6.215289, test error 54.25
# Epoch   600, train loss 0.004459, train error 0.00,  test loss 6.573500, test error 54.47
# Epoch   700, train loss 0.003426, train error 0.00,  test loss 6.866413, test error 54.58
# Epoch   800, train loss 0.002749, train error 0.00,  test loss 7.102704, test error 54.72
# Epoch   900, train loss 0.002288, train error 0.00,  test loss 7.304211, test error 54.65
# Training model with  70 hidden variables
# Epoch     0, train loss 2.034740, train error 76.35,  test loss 1.967700, test error 76.25
# Epoch   100, train loss 0.350646, train error 8.12,  test loss 1.923178, test error 51.20
# Epoch   200, train loss 0.035838, train error 0.03,  test loss 3.585140, test error 54.35
# Epoch   300, train loss 0.011686, train error 0.00,  test loss 4.384645, test error 54.67
# Epoch   400, train loss 0.006379, train error 0.00,  test loss 4.832890, test error 54.67
# Epoch   500, train loss 0.004278, train error 0.00,  test loss 5.136545, test error 54.72
# Epoch   600, train loss 0.003157, train error 0.00,  test loss 5.373994, test error 54.83
# Epoch   700, train loss 0.002477, train error 0.00,  test loss 5.562875, test error 54.83
# Epoch   800, train loss 0.002021, train error 0.00,  test loss 5.724246, test error 54.83
# Epoch   900, train loss 0.001697, train error 0.00,  test loss 5.861484, test error 54.83
# Training model with  80 hidden variables
# Epoch     0, train loss 2.028294, train error 74.12,  test loss 1.955074, test error 73.82
# Epoch   100, train loss 0.238629, train error 4.10,  test loss 2.190773, test error 52.12
# Epoch   200, train loss 0.020701, train error 0.00,  test loss 3.667152, test error 53.30
# Epoch   300, train loss 0.008115, train error 0.00,  test loss 4.256564, test error 53.50
# Epoch   400, train loss 0.004823, train error 0.00,  test loss 4.611392, test error 53.45
# Epoch   500, train loss 0.003330, train error 0.00,  test loss 4.858269, test error 53.40
# Epoch   600, train loss 0.002502, train error 0.00,  test loss 5.053684, test error 53.55
# Epoch   700, train loss 0.001985, train error 0.00,  test loss 5.210467, test error 53.60
# Epoch   800, train loss 0.001634, train error 0.00,  test loss 5.342448, test error 53.67
# Epoch   900, train loss 0.001381, train error 0.00,  test loss 5.457915, test error 53.67
# Training model with  90 hidden variables
# Epoch     0, train loss 1.992065, train error 74.07,  test loss 1.926074, test error 73.32
# Epoch   100, train loss 0.142033, train error 0.85,  test loss 2.234461, test error 52.42
# Epoch   200, train loss 0.014769, train error 0.00,  test loss 3.366465, test error 53.35
# Epoch   300, train loss 0.006518, train error 0.00,  test loss 3.819863, test error 53.60
# Epoch   400, train loss 0.003998, train error 0.00,  test loss 4.094616, test error 53.60
# Epoch   500, train loss 0.002809, train error 0.00,  test loss 4.297803, test error 53.78
# Epoch   600, train loss 0.002137, train error 0.00,  test loss 4.451970, test error 53.80
# Epoch   700, train loss 0.001708, train error 0.00,  test loss 4.579345, test error 53.80
# Epoch   800, train loss 0.001415, train error 0.00,  test loss 4.687837, test error 53.70
# Epoch   900, train loss 0.001201, train error 0.00,  test loss 4.782207, test error 53.67
# Training model with 100 hidden variables
# Epoch     0, train loss 2.009735, train error 75.43,  test loss 1.954543, test error 76.78
# Epoch   100, train loss 0.095443, train error 0.12,  test loss 2.271066, test error 51.33
# Epoch   200, train loss 0.012184, train error 0.00,  test loss 3.141243, test error 50.95
# Epoch   300, train loss 0.005652, train error 0.00,  test loss 3.504137, test error 50.55
# Epoch   400, train loss 0.003527, train error 0.00,  test loss 3.734321, test error 50.67
# Epoch   500, train loss 0.002511, train error 0.00,  test loss 3.901460, test error 50.67
# Epoch   600, train loss 0.001925, train error 0.00,  test loss 4.031237, test error 50.72
# Epoch   700, train loss 0.001547, train error 0.00,  test loss 4.139701, test error 50.83
# Epoch   800, train loss 0.001285, train error 0.00,  test loss 4.231484, test error 50.92
# Epoch   900, train loss 0.001094, train error 0.00,  test loss 4.311378, test error 50.90
# Training model with 120 hidden variables
# Epoch     0, train loss 1.973652, train error 73.12,  test loss 1.896521, test error 74.50
# Epoch   100, train loss 0.050772, train error 0.00,  test loss 2.381886, test error 51.90
# Epoch   200, train loss 0.009437, train error 0.00,  test loss 3.037056, test error 51.95
# Epoch   300, train loss 0.004695, train error 0.00,  test loss 3.340923, test error 52.17
# Epoch   400, train loss 0.003000, train error 0.00,  test loss 3.534763, test error 51.95
# Epoch   500, train loss 0.002162, train error 0.00,  test loss 3.679692, test error 52.12
# Epoch   600, train loss 0.001671, train error 0.00,  test loss 3.791096, test error 52.00
# Epoch   700, train loss 0.001350, train error 0.00,  test loss 3.885749, test error 52.03
# Epoch   800, train loss 0.001127, train error 0.00,  test loss 3.965120, test error 52.03
# Epoch   900, train loss 0.000963, train error 0.00,  test loss 4.035259, test error 52.03
# Training model with 140 hidden variables
# Epoch     0, train loss 1.983036, train error 72.93,  test loss 1.908175, test error 73.45
# Epoch   100, train loss 0.034803, train error 0.00,  test loss 2.239271, test error 50.85
# Epoch   200, train loss 0.007924, train error 0.00,  test loss 2.722848, test error 50.58
# Epoch   300, train loss 0.004084, train error 0.00,  test loss 2.956883, test error 50.25
# Epoch   400, train loss 0.002655, train error 0.00,  test loss 3.105713, test error 50.05
# Epoch   500, train loss 0.001935, train error 0.00,  test loss 3.219595, test error 50.20
# Epoch   600, train loss 0.001506, train error 0.00,  test loss 3.311035, test error 50.22
# Epoch   700, train loss 0.001223, train error 0.00,  test loss 3.385122, test error 50.10
# Epoch   800, train loss 0.001025, train error 0.00,  test loss 3.449521, test error 50.05
# Epoch   900, train loss 0.000879, train error 0.00,  test loss 3.506135, test error 50.12
# Training model with 160 hidden variables
# Epoch     0, train loss 1.949654, train error 71.65,  test loss 1.881992, test error 73.12
# Epoch   100, train loss 0.027912, train error 0.00,  test loss 2.173355, test error 49.12
# Epoch   200, train loss 0.007051, train error 0.00,  test loss 2.588677, test error 49.08
# Epoch   300, train loss 0.003725, train error 0.00,  test loss 2.795649, test error 49.00
# Epoch   400, train loss 0.002456, train error 0.00,  test loss 2.936160, test error 49.12
# Epoch   500, train loss 0.001800, train error 0.00,  test loss 3.039729, test error 49.05
# Epoch   600, train loss 0.001407, train error 0.00,  test loss 3.122653, test error 49.15
# Epoch   700, train loss 0.001147, train error 0.00,  test loss 3.190548, test error 49.17
# Epoch   800, train loss 0.000963, train error 0.00,  test loss 3.250077, test error 49.17
# Epoch   900, train loss 0.000827, train error 0.00,  test loss 3.301147, test error 49.15
# Training model with 180 hidden variables
# Epoch     0, train loss 1.965772, train error 70.43,  test loss 1.888009, test error 72.97
# Epoch   100, train loss 0.024179, train error 0.00,  test loss 2.199468, test error 49.92
# Epoch   200, train loss 0.006571, train error 0.00,  test loss 2.593253, test error 50.25
# Epoch   300, train loss 0.003506, train error 0.00,  test loss 2.796052, test error 50.33
# Epoch   400, train loss 0.002323, train error 0.00,  test loss 2.926412, test error 50.30
# Epoch   500, train loss 0.001711, train error 0.00,  test loss 3.025564, test error 50.12
# Epoch   600, train loss 0.001340, train error 0.00,  test loss 3.104847, test error 50.20
# Epoch   700, train loss 0.001094, train error 0.00,  test loss 3.169709, test error 50.10
# Epoch   800, train loss 0.000920, train error 0.00,  test loss 3.226616, test error 50.12
# Epoch   900, train loss 0.000791, train error 0.00,  test loss 3.275549, test error 50.12
# Training model with 200 hidden variables
# Epoch     0, train loss 1.901111, train error 69.20,  test loss 1.804234, test error 70.47
# Epoch   100, train loss 0.020758, train error 0.00,  test loss 1.985491, test error 47.58
# Epoch   200, train loss 0.006040, train error 0.00,  test loss 2.301230, test error 47.65
# Epoch   300, train loss 0.003284, train error 0.00,  test loss 2.460158, test error 47.58
# Epoch   400, train loss 0.002192, train error 0.00,  test loss 2.568856, test error 47.47
# Epoch   500, train loss 0.001620, train error 0.00,  test loss 2.650958, test error 47.47
# Epoch   600, train loss 0.001273, train error 0.00,  test loss 2.716682, test error 47.45
# Epoch   700, train loss 0.001041, train error 0.00,  test loss 2.771644, test error 47.47
# Epoch   800, train loss 0.000877, train error 0.00,  test loss 2.818586, test error 47.40
# Epoch   900, train loss 0.000755, train error 0.00,  test loss 2.860276, test error 47.42
# Training model with 250 hidden variables
# Epoch     0, train loss 1.911418, train error 69.85,  test loss 1.812537, test error 71.60
# Epoch   100, train loss 0.016889, train error 0.00,  test loss 1.934444, test error 47.83
# Epoch   200, train loss 0.005326, train error 0.00,  test loss 2.193453, test error 47.90
# Epoch   300, train loss 0.002978, train error 0.00,  test loss 2.330540, test error 48.03
# Epoch   400, train loss 0.002009, train error 0.00,  test loss 2.424122, test error 47.95
# Epoch   500, train loss 0.001495, train error 0.00,  test loss 2.494312, test error 47.85
# Epoch   600, train loss 0.001180, train error 0.00,  test loss 2.551401, test error 47.83
# Epoch   700, train loss 0.000969, train error 0.00,  test loss 2.599381, test error 47.95
# Epoch   800, train loss 0.000818, train error 0.00,  test loss 2.640105, test error 47.83
# Epoch   900, train loss 0.000706, train error 0.00,  test loss 2.676142, test error 47.80
# Training model with 300 hidden variables
# Epoch     0, train loss 1.872505, train error 66.35,  test loss 1.805127, test error 69.47
# Epoch   100, train loss 0.014291, train error 0.00,  test loss 1.889881, test error 47.60
# Epoch   200, train loss 0.004796, train error 0.00,  test loss 2.111525, test error 47.38
# Epoch   300, train loss 0.002721, train error 0.00,  test loss 2.233220, test error 47.47
# Epoch   400, train loss 0.001853, train error 0.00,  test loss 2.314919, test error 47.22
# Epoch   500, train loss 0.001387, train error 0.00,  test loss 2.377682, test error 47.20
# Epoch   600, train loss 0.001099, train error 0.00,  test loss 2.428664, test error 47.17
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.472409, test error 47.28
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.508928, test error 47.17
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.541607, test error 47.28
# Training model with 400 hidden variables
# Epoch     0, train loss 1.880309, train error 67.18,  test loss 1.804469, test error 71.40
# Epoch   100, train loss 0.011562, train error 0.00,  test loss 1.805073, test error 47.50
# Epoch   200, train loss 0.004141, train error 0.00,  test loss 1.982466, test error 47.05
# Epoch   300, train loss 0.002402, train error 0.00,  test loss 2.080740, test error 47.00
# Epoch   400, train loss 0.001656, train error 0.00,  test loss 2.151240, test error 46.70
# Epoch   500, train loss 0.001249, train error 0.00,  test loss 2.205085, test error 46.65
# Epoch   600, train loss 0.000995, train error 0.00,  test loss 2.248004, test error 46.70
# Epoch   700, train loss 0.000822, train error 0.00,  test loss 2.285238, test error 46.70
# Epoch   800, train loss 0.000698, train error 0.00,  test loss 2.316555, test error 46.78
# Epoch   900, train loss 0.000605, train error 0.00,  test loss 2.344912, test error 46.83

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
